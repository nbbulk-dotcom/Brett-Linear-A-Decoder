# %% [markdown]
# # Linear A Decoder v2.2 - HT85 Decoding Example
#
# This notebook demonstrates the complete decoding process for tablet HT85.

# %%
import sys
sys.path.append('../src')

from enhanced_linear_a_decoder_v2_2 import EnhancedLinearADecoder
import json

decoder = EnhancedLinearADecoder()
reading = decoder.read_tablet('HT85')
print(reading.interpretation)
